# %%
import os, sys
from PIL import Image
os.chdir('..')
from src.yolo import Yolo

# %%
yolo = Yolo()

# %%
image = Image.open('images/2.jpg')
yolo.detect_image(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x13C26FFD0>

# %%
image = Image.open('images/11.jpg')
yolo.detect_image(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x428 at 0x13C26FDD0>

# %%
image = Image.open('images/15.jpg')
yolo.detect_image(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x465 at 0x13C26F9D0>
